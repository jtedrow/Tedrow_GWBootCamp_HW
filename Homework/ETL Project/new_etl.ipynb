# %%
import pandas as pd

# %%
money_sent_file = "API_BX.TRF.PWKR.CD_DS2_en_csv_v2_41308.csv"
countries = "countries.csv"

# %%
money_df = pd.read_csv(money_sent_file)
countries_df = pd.read_csv(countries)
money_df.rename(columns={"Country Name":"Country"}, inplace=True)

# %%
#Drop unnecessary columns
money_df.drop(columns = ["Country Code", "Indicator Name", "Indicator Code"], inplace=True)
money_df
# Out:
#                                                Country  1960  1961  1962  \
# 0                                                Aruba   NaN   NaN   NaN
# 1                                          Afghanistan   NaN   NaN   NaN
# 2                                               Angola   NaN   NaN   NaN
# 3                                              Albania   NaN   NaN   NaN
# 4                                              Andorra   NaN   NaN   NaN
# 5                                           Arab World   NaN   NaN   NaN
# 6                                 United Arab Emirates   NaN   NaN   NaN
# 7                                            Argentina   NaN   NaN   NaN
# 8                                              Armenia   NaN   NaN   NaN
# 9                                       American Samoa   NaN   NaN   NaN
# 10                                 Antigua and Barbuda   NaN   NaN   NaN
# 11                                           Australia   NaN   NaN   NaN
# ...

# %%
money_df.set_index("Country", inplace=True)
money_df = money_df.iloc[:,-11:]
money_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\james\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Country'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-69-d2bac85eaf15> in <module>
# ...

# %%
#Convert data into floats to allow addition
money_df.set_index("Country", inplace=True)
for col in money_df.columns:
    money_df[col] = money_df[col].str.replace("$","")
    money_df[col] = money_df[col].str.replace(",","")
    money_df[col] = money_df[col].str.replace("-","")
    money_df[col] = money_df[col].str.replace(")","")
    money_df[col] = money_df[col].astype(float)

# %%
#Create a total column and sum the rows
money_df.loc[:,'Total'] = money_df.sum(axis=1)

# %%
countries_df.set_index("Country", inplace=True)

# %%
countries_df
# Out:
#                                                     Region  Population  \
# Country
# Afghanistan                  ASIA (EX. NEAR EAST)             31056997
# Albania                EASTERN EUROPE                          3581655
# Algeria                NORTHERN AFRICA                        32930091
# American Samoa         OCEANIA                                   57794
# Andorra                WESTERN EUROPE                            71201
# Angola                 SUB-SAHARAN AFRICA                     12127071
# Anguilla                           LATIN AMER. & CARIB           13477
# Antigua & Barbuda                  LATIN AMER. & CARIB           69108
# Argentina                          LATIN AMER. & CARIB        39921833
# Armenia                               C.W. OF IND. STATES      2976372
# Aruba                              LATIN AMER. & CARIB           71891
# Australia              OCEANIA                                20264082
# ...

# %%
money_df
# Out:
#                                                             2008  \
# Country
# Aruba                                               1.843575e+06
# Afghanistan                                         1.763641e+07
# Angola                                              7.104200e+07
# Albania                                             1.595885e+09
# Andorra                                                      NaN
# Arab World                                                   NaN
# United Arab Emirates                                         NaN
# Argentina                                           6.059200e+08
# Armenia                                             8.372899e+08
# American Samoa                                               NaN
# Antigua and Barbuda                                 1.253459e+07
# Australia                                                    NaN
# Austria                                             5.191512e+08
# ...

# %%
countries_df.merge(money_df,right_index=True, left_index=True, how="outer")
# Out:
#                                                     Region   Population  \
# Country
# Afghanistan                                            NaN          NaN
# Afghanistan                  ASIA (EX. NEAR EAST)            31056997.0
# Albania                                                NaN          NaN
# Albania                EASTERN EUROPE                         3581655.0
# Algeria                                                NaN          NaN
# Algeria                NORTHERN AFRICA                       32930091.0
# American Samoa                                         NaN          NaN
# American Samoa         OCEANIA                                  57794.0
# Andorra                                                NaN          NaN
# Andorra                WESTERN EUROPE                           71201.0
# Angola                                                 NaN          NaN
# Angola                 SUB-SAHARAN AFRICA                    12127071.0
# ...

# %%
countries_df.reset_index(inplace=True)

# %%
countries_df["Country"] = countries_df["Country"].str.replace(" ","")

# %%
countries_df.set_index("Country", inplace=True)

# %%
countries_df.index
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'AmericanSamoa', 'Andorra',
#        'Angola', 'Anguilla', 'Antigua&Barbuda', 'Argentina', 'Armenia',
#        ...
#        'Vanuatu', 'Venezuela', 'Vietnam', 'VirginIslands', 'WallisandFutuna',
#        'WestBank', 'WesternSahara', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='Country', length=227)

# %%
joined_df = countries_df.merge(money_df,right_index=True, left_index=True, how="inner")

# %%
joined_df.sort_values("Total", ascending=False)
# Out:
#                                             Region  Population  \
# Country
# India                ASIA (EX. NEAR EAST)           1095351995
# Mexico                     LATIN AMER. & CARIB       107449525
# Philippines          ASIA (EX. NEAR EAST)             89468677
# Nigeria        SUB-SAHARAN AFRICA                    131859731
# Pakistan             ASIA (EX. NEAR EAST)            165803560
# Bangladesh           ASIA (EX. NEAR EAST)            147365352
# Indonesia            ASIA (EX. NEAR EAST)            245452739
# Morocco        NORTHERN AFRICA                        33241259
# Guatemala                  LATIN AMER. & CARIB        12293545
# Lebanon        NEAR EAST                               3874050
# Colombia                   LATIN AMER. & CARIB        43593035
# Nepal                ASIA (EX. NEAR EAST)             28287147
# Thailand             ASIA (EX. NEAR EAST)             64631595
# Poland         EASTERN EUROPE                         38536869
# ...

# %%
from sqlalchemy import create_engine

engine = create_engine(
    f'postgresql+psycopg2://postgres:{password}@localhost/{tablename}')
